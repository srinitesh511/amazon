# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/employee.csv')

# %%
data
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
data.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
data.groupby('Age').count()
# Out:
#      EmployeeID  Attrition  BusinessTravel  Department  DistanceFromHome  \
# Age
# 18           24         24              24          24                24
# 19           27         27              27          27                27
# 20           33         33              33          33                33
# 21           39         39              39          39                39
# 22           48         48              48          48                48
# 23           42         42              42          42                42
# 24           78         78              78          78                78
# 25           78         78              78          78                78
# 26          117        117             117         117               117
# 27          144        144             144         144               144
# 28          144        144             144         144               144
# 29          204        204             204         204               204
# ...

# %%
from matplotlib import pyplot as plt
_df_12['Age'].plot(kind='line', figsize=(8, 4), title='Age')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_13['EmployeeID'].plot(kind='line', figsize=(8, 4), title='EmployeeID')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_14['Attrition'].plot(kind='line', figsize=(8, 4), title='Attrition')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_15['BusinessTravel'].plot(kind='line', figsize=(8, 4), title='BusinessTravel')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Age']
  ys = series['EmployeeID']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_8.sort_values('Age', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Age')
_ = plt.ylabel('EmployeeID')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Age']
  ys = series['Attrition']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_9.sort_values('Age', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Age')
_ = plt.ylabel('Attrition')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Age']
  ys = series['BusinessTravel']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_10.sort_values('Age', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Age')
_ = plt.ylabel('BusinessTravel')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Age']
  ys = series['Department']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_11.sort_values('Age', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Age')
_ = plt.ylabel('Department')

# %%
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='Age', y='EmployeeID', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5.plot(kind='scatter', x='EmployeeID', y='Attrition', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='Attrition', y='BusinessTravel', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_7.plot(kind='scatter', x='BusinessTravel', y='Department', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['EmployeeID'].plot(kind='hist', bins=20, title='EmployeeID')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_2['Attrition'].plot(kind='hist', bins=20, title='Attrition')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['BusinessTravel'].plot(kind='hist', bins=20, title='BusinessTravel')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.groupby('BusinessTravel').count()
# Out:
#                    EmployeeID   Age  Attrition  Department  DistanceFromHome  \
# BusinessTravel
# Non-Travel                450   450        450         450               450
# Travel_Frequently         831   831        831         831               831
# Travel_Rarely            3129  3129       3129        3129              3129
#
#                    Education  EducationField  EmployeeCount  Gender  JobLevel  \
# BusinessTravel
# Non-Travel               450             450            450     450       450
# Travel_Frequently        831             831            831     831       831
# Travel_Rarely           3129            3129           3129    3129      3129
#
#                    ...  TotalWorkingYears  TrainingTimesLastYear  \
# BusinessTravel     ...
# Non-Travel         ...                449                    450
# Travel_Frequently  ...                829                    831
# Travel_Rarely      ...               3123                   3129
#
# ...

# %%
data.groupby('Attrition').count()
# Out:
#            EmployeeID   Age  BusinessTravel  Department  DistanceFromHome  \
# Attrition
# No               3699  3699            3699        3699              3699
# Yes               711   711             711         711               711
#
#            Education  EducationField  EmployeeCount  Gender  JobLevel  ...  \
# Attrition                                                              ...
# No              3699            3699           3699    3699      3699  ...
# Yes              711             711            711     711       711  ...
#
#            TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# Attrition
# No                      3692                   3699            3699
# Yes                      709                    711             711
#
#            YearsSinceLastPromotion  YearsWithCurrManager  \
# Attrition
# No                            3699                  3699
# Yes                            711                   711
#
# ...

# %%
data.groupby('Department').count()
# Out:
#                         EmployeeID   Age  Attrition  BusinessTravel  \
# Department
# Human Resources                189   189        189             189
# Research & Development        2883  2883       2883            2883
# Sales                         1338  1338       1338            1338
#
#                         DistanceFromHome  Education  EducationField  \
# Department
# Human Resources                      189        189             189
# Research & Development              2883       2883            2883
# Sales                               1338       1338            1338
#
#                         EmployeeCount  Gender  JobLevel  ...  \
# Department                                               ...
# Human Resources                   189     189       189  ...
# Research & Development           2883    2883      2883  ...
# Sales                            1338    1338      1338  ...
#
#                         TotalWorkingYears  TrainingTimesLastYear  \
# Department
# ...

# %%
data.groupby('DistanceFromHome').count()
# Out:
#                   EmployeeID  Age  Attrition  BusinessTravel  Department  \
# DistanceFromHome
# 1                        624  624        624             624         624
# 2                        633  633        633             633         633
# 3                        252  252        252             252         252
# 4                        192  192        192             192         192
# 5                        195  195        195             195         195
# 6                        177  177        177             177         177
# 7                        252  252        252             252         252
# 8                        240  240        240             240         240
# 9                        255  255        255             255         255
# 10                       258  258        258             258         258
# 11                        87   87         87              87          87
# 12                        60   60         60              60          60
# ...

# %%
data.groupby('EducationField').count()
# Out:
#                   EmployeeID   Age  Attrition  BusinessTravel  Department  \
# EducationField
# Human Resources           81    81         81              81          81
# Life Sciences           1818  1818       1818            1818        1818
# Marketing                477   477        477             477         477
# Medical                 1392  1392       1392            1392        1392
# Other                    246   246        246             246         246
# Technical Degree         396   396        396             396         396
#
#                   DistanceFromHome  Education  EmployeeCount  Gender  \
# EducationField
# Human Resources                 81         81             81      81
# Life Sciences                 1818       1818           1818    1818
# Marketing                      477        477            477     477
# Medical                       1392       1392           1392    1392
# Other                          246        246            246     246
# ...

# %%
data.groupby('EmployeeCount').count()
# Out:
#                EmployeeID   Age  Attrition  BusinessTravel  Department  \
# EmployeeCount
# 1                    4410  4410       4410            4410        4410
#
#                DistanceFromHome  Education  EducationField  Gender  JobLevel  \
# EmployeeCount
# 1                          4410       4410            4410    4410      4410
#
#                ...  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# EmployeeCount  ...
# 1              ...               4401                   4410            4410
#
#                YearsSinceLastPromotion  YearsWithCurrManager  \
# EmployeeCount
# 1                                 4410                  4410
#
#                EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# EmployeeCount
# 1                                 4385             4390             4372
#
#                JobInvolvement  PerformanceRating
# EmployeeCount
# 1                        4410               4410
#
# [1 rows x 28 columns]
